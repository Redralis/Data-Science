# %% [markdown]
# # De taken en het proces van een Data Scientist

# %% [markdown]
# De taken en het proces van een Data Scientist lopen natuurlijk heel erg samen met wat er in assignment 101 is uitgelegd. Een Data Scientist analyseert gegevens die uit een dataset komen en zoekt daarmee naar correlaties en doet voorspellingen. Onderstaand voorbeeld uit assignment 10 laat een voorbeeld zien van hoe een Data Scientist naar correlaties zoekt:

# %% [markdown]
# ![b5fd2955ac0005cc2d95415d201bd176.png](attachment:b5fd2955ac0005cc2d95415d201bd176.png)

# %% [markdown]
# Er wordt hier met 'corr()' gekeken of er een correlatie zit tussen 'HP' en 'Weight'. Hier zit een degelijke correlatie tussen op basis van de dataset, en dit wordt dan uitgebeeld in een scatter plot:

# %% [markdown]
# ![f53faf50bf623e58814478874becbe8a.png](attachment:f53faf50bf623e58814478874becbe8a.png)

# %% [markdown]
# Naast correlaties tonen worden er ook voorspellingen gedaan. Dit wordt uitgebeeld in het volgende voorbeeld, uit assignment 18:

# %% [markdown]
# ![6d5eccd64572c420a6f175ccfb714a05.png](attachment:6d5eccd64572c420a6f175ccfb714a05.png)

# %% [markdown]
# Hier wordt een decision tree eerst getraint, en dan gevraagd om het gewicht van een Pokemon te voorspellen op basis van zijn stats:

# %% [markdown]
# ![0b68ec795a4b361ff7b4959621ae347c.png](attachment:0b68ec795a4b361ff7b4959621ae347c.png)

# %% [markdown]
# In het kort: een Data Scientist analyseert, zoekt naar correlaties en doet voorspellingen.
