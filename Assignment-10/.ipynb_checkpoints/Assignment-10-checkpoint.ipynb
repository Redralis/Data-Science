# %% [markdown]
# # Importing...

# %%
import pandas as pd

# %%
import seaborn as sns

# %%
pokemon = pd.read_csv('../Dataset.csv', sep=',')

# %% [markdown]
# # Bivariate analysis on the correlation between 2 numerical columns...

# %% [markdown]
# I expect a mild to strong correlation between the HP (hit points) and the weight of a pokemon based on personal experience playing the games.

# %%
pokemon[['HP','Weight']].corr().style.background_gradient(cmap='coolwarm', axis=None).format(precision=2)
# Out:
# <style type="text/css">
# #T_5c5eb_row0_col0, #T_5c5eb_row1_col1 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_5c5eb_row0_col1, #T_5c5eb_row1_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_5c5eb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5c5eb_level0_col0" class="col_heading level0 col0" >HP</th>
#       <th id="T_5c5eb_level0_col1" class="col_heading level0 col1" >Weight</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5c5eb_level0_row0" class="row_heading level0 row0" >HP</th>
#       <td id="T_5c5eb_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_5c5eb_row0_col1" class="data row0 col1" >0.44</td>
#     </tr>
#     <tr>
#       <th id="T_5c5eb_level0_row1" class="row_heading level0 row1" >Weight</th>
#       <td id="T_5c5eb_row1_col0" class="data row1 col0" >0.44</td>
#       <td id="T_5c5eb_row1_col1" class="data row1 col1" >1.00</td>
#     </tr>
#   </tbody>
# </table>

# %%
pokemon.plot(kind='scatter', x='HP', y='Weight')
# Out:
# <AxesSubplot:xlabel='HP', ylabel='Weight'>

# %% [markdown]
# There is a mild correlation between HP and Weight as is visible in the table and scatter plot.
