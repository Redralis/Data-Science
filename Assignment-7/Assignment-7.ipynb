# %% [markdown]
# # Importing...

# %%
import pandas as pd

# %%
import seaborn as sns

# %%
pokemon = pd.read_csv('../Dataset.csv', sep=',')

# %% [markdown]
# # Creating the histograms of numerical columns and naming the distribution...

# %%
pokemon['HP'].plot(kind='hist', bins = 10)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# The distribution of the HP stat in all pokemon looks like an Extreme Value Type 1 distribution, because the amount of pokemon with low HP is very small compared to the amount of pokemon with a large amount of HP, while the rest of the distribution is normal.

# %%
pokemon['Def'].plot(kind='hist', bins = 10)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# The distribution of the Speed stat in all pokemon looks like an Extreme Value Type 1 distribution, because the amount of pokemon with low Speed is very small compared to the amount of pokemon with a large amount of Speed, while the rest of the distribution is normal.
